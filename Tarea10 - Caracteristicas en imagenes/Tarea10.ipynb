# %% [markdown]
# # **TAREA 10 - VISIÓN DE MÁQUINA**
#
# **Universidad Nacional de Colombia** <br>
# **Maestría en Ingeniería - Automatización industrial**
#
# Juan Sebastián Hernandez Reyes; Julián Felipe Molina Grisales

# %% [markdown]
# ### 1. Implementar, como una función en python, los momentos de Flusser y Suk, y compararlos contra los momentos de Hu, como descriptores de imágenes.
#
# ---
#
# ---

# %% [markdown]
# ### 2. Implementar, como una función en python, alguno de los siguientes momentos ortogonales para imágenes:
#
# *   Momentos de Legendre.
# *   Momentos de Zernike.
#
# y compararlos contra los momentos no ortogonales, como
# descriptores de imágenes.
#
# ---
#
# ---

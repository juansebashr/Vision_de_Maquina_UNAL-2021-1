# %% [markdown]
# # **TAREA 13 - VISIÓN DE MÁQUINA**
# ## **Clasificadores basados en funciones discriminantes**
#
# **Universidad Nacional de Colombia** <br>
# **Maestría en Ingeniería - Automatización industrial**
#
# Juan Sebastián Hernandez Reyes; Julián Felipe Molina Grisales

# %% [markdown]
# ### 1. Estudiar y evaluar el clasificador lineal **Probabilistic Generative Model para K-clases**, descrito en el libro “Pattern Recognition and Machine Learning” by Christopher M Bishop (p 196, Sección 4.2).
#
# ---
#
# ---
